# %%
import requests

# %%
r = requests.get('https://api.github.com/events')
r
# Out:
# <Response [200]>

# %%
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://api.github.com/events'

# %%
r.text
# Out:
# '[{"id":"47480350887","type":"IssueCommentEvent","actor":{"id":133711747,"login":"tyriis-automation[bot]","display_login":"tyriis-automation","gravatar_id":"","url":"https://api.github.com/users/tyriis-automation[bot]","avatar_url":"https://avatars.githubusercontent.com/u/133711747?"},"repo":{"id":452012446,"name":"tyriis/home-ops","url":"https://api.github.com/repos/tyriis/home-ops"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/tyriis/home-ops/issues/4729","repository_url":"https://api.github.com/repos/tyriis/home-ops","labels_url":"https://api.github.com/repos/tyriis/home-ops/issues/4729/labels{/name}","comments_url":"https://api.github.com/repos/tyriis/home-ops/issues/4729/comments","events_url":"https://api.github.com/repos/tyriis/home-ops/issues/4729/events","html_url":"https://github.com/tyriis/home-ops/pull/4729","id":2914109649,"node_id":"PR_kwDOGvEpns6OWlaO","number":4729,"title":"fix(deps): update dependency talosctl ( 1.9.4 → 1.9.5 )","user":{"login":"tyriis-automation[bot]","id":133711747,"node_id":"BOT_kgDOB_hHgw","avatar_url":"https://avatars.githubusercontent.com/in/334186?v=4","gravatar_id":"","url":"https://api.github.com/users/tyriis-automation%5Bbot%5D","html_url":"https://github.com/apps/tyriis-automation","followers_url":"https://api.github.com/users/tyriis-automation%5Bbot%5D/followers","following_url":"https://api.github.com/users/tyriis-automation%5Bbot%5D/following{/other_user}","gists_url":"https://api.github.com/users/tyriis-automation%5Bbot%5D/gists{/gist_id}","starred_url":"https://api.github.com/users/tyriis-automation%5Bbot%5D/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/tyriis-automation%5Bbot%5D/subscriptions","organizations_url":"https://api.github.com/users/tyriis-automation%5Bbot%5D/orgs","repos_url":"https://api.github.com/users/tyriis-automation%5Bbot%5D/repos","events_url":"https://api.github.com/users/tyriis-automation%5Bbot%5D/events{/privacy}","received_events_url":"https://api.github.com/users/tyriis-automation%5Bbot%5D/received_events","type":"Bot","user_view_type":"public","site_admin":false},"labels":[{"id":4243118395,"node_id":"LA_kwDOGvEpns786Nk7","url":"https://api.github.com/repos/tyriis/home-ops/labels/type/patch","name":"type/patch","color":"0e8a16","default":false,"description":"a patch for a bug"},{"id":6327204260,"node_id":"LA_kwDOGvEpns8AAAABeSF5pA","url":"https://api.github.com/repos/tyriis/home-ops/labels/renovate/github-tag","name":"renovate/github-tag","color":"ededed","default":false,"description":null}],"state":"open","locked":false,"assignee":null,"assignees":[],"milestone":null,"comments":2,"created_at":"2025-03-12T14:08:48Z","updated_at":"2025-03-12T14:09:56Z","closed_at":null,"author_association":"CONTRIBUTOR","sub_issues_summary":{"total":0,"completed":0,"percent_completed":0},"active_lock_reason":null,"draft":false,"pull_request":{"url":"https://api.github.com/repos/tyriis/home-ops/pulls/4729","html_url":"https://github.com/tyriis/home-ops/pull/4729","diff_url":"https://github.com/tyriis/home-ops/pull/4729.diff","patch_url":"https://github.com/tyriis/home-ops/pull/4729.patch","merged_at":null},"body":"This PR contains the following updates:\\n\\n| Package | Update | Change | OpenSSF |\\n|---|---|---|---|\\n| [talosctl](https://redirect.github.com/siderolabs/talos) | patch | `1.9.4` -> `1.9.5` | [![OpenSSF Scorecard](https://api.securityscorecards.dev/projects/github.com/siderolabs/talos/badge)](https://securityscorecards.dev/viewer/?uri=github.com/siderolabs/talos) |\\n\\n---\\n\\n> [!WARNING]\\n> Some dependencies could not be looked up. Check the Dependency Dashboard for more information.\\n\\n---\\n\\n### Release Notes\\n\\n<details>\\n<summary>siderolabs/talos (talosctl)</summary>\\n\\n### [`v1.9.5`](https://redirect.github.com/siderolabs/talos/compare/v1.9.4...v1.9.5)\\n\\n[Compare Source](https://redirect.github.com/siderolabs/talos/compare/v1.9.4...v1.9.5)\\n\\n</details>\\n\\n---\\n\\n### Confi ...

# %%
r.json()

# %%
r = requests.get('https://api.github.com/versions')
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# ['2022-11-28']

# %%
# especificando a versão da API
headers = {'X-GitHub-Api-Version': '2022-11-28'}

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn' # username de quem vamos extrair os dados
url = f'{api_base_url}/users/{owner}/repos'

# %%
url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
response = requests.get(url, headers=headers)
response.status_code
# Out:
# 200

# %%
response.json()

# %%
len(response.json())
# Out:
# 30

# %%
access_token = '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ttt'
headers = {'Authorization': 'Bearer' + access_token,
           'X-GitHub-Api-Version': '2022-11-28'}

# %% [markdown]
# PAGINANDO REPOSITÓRIO

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn' # username de quem vamos extrair os dados
url = f'{api_base_url}/users/{owner}/repos'
url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
repos_list = []
for page_num in range(1,6):
    try:
        url_page = f'{url}?page={page_num}'
        response = requests.get(url_page, headers=headers)
        repos_list.append(response.json())
    except:
        repos_list.append(None)

# %%
repos_list

# %%
len(repos_list)
len(repos_list[0])
# Out:
# 30

# %% [markdown]
# TRANSFORMANDO DADOS
# Nomes dos repositórios

# %%
repos_list[0][1]['name']
# Out:
# 'ads-advanced-tools-docs'

# %%
repos_name = []
for page in repos_list:
    for repo in page:
        repos_name.append(repo['name'])

# %%
repos_name[5:10]
# Out:
# ['amazon-ads-advertiser-audience-normalization-sdk-py',
#  'amazon-advertising-api-php-sdk',
#  'amazon-codeguru-profiler-for-spark',
#  'amazon-frustration-free-setup-certification-tool',
#  'amazon-hub-counter-api-docs']

# %%
len(repos_name)
# Out:
# 150

# %% [markdown]
# Linguagens dos repostórios

# %%
repos_list[1][1]['language']
# Out:
# 'Ruby'

# %%
repos_language = []
for page in repos_list:
    for repo in page:
        repos_language.append(repo['language'])

# %%
len(repos_language)
# Out:
# 150

# %%
repos_language[5:10]
# Out:
# ['Python', 'PHP', 'Java', 'Python', 'CSS']

# %% [markdown]
# Criando um DataFrame

# %%
import pandas as pd

# %%
dados_amz = pd.DataFrame()
dados_amz['repository_name'] = repos_name
dados_amz['language'] = repos_language

# %%
dados_amz
# Out:
#                          repository_name          language
# 0                                .github              None
# 1                ads-advanced-tools-docs  Jupyter Notebook
# 2            ads-pao-amznjs-gtm-template            Smarty
# 3                             alexa-coho        JavaScript
# 4                    alexa-skills-kit-js              None
# ..                                   ...               ...
# 145  supply-chain-simulation-environment            Python
# 146           tiny-attribution-generator        TypeScript
# 147   traffic-quality-smart-pixel-loader        TypeScript
# 148                        trans-encoder            Python
# 149           user-satisfaction-modeling            Python
#
# [150 rows x 2 columns]

# %% [markdown]
# Salvando o Data Frame

# %%
dados_amz.to_csv('amazon.csv')

# %% [markdown]
# Criando repositório com post

# %%
api_base_url = 'https://api.github.com'
url = f'{api_base_url}/user/repos'

url
# Out:
# 'https://api.github.com/user/repos'

# %%
data = {
    'name': 'linguagens-utilizadas',
    'description': 'Repositorio com as linguagens de prog da Amazon',
    'private': False
}

response = requests.post(url, json=data, headers=headers)
response.status_code
# Out:
# 401

# %% [markdown]
# Formato do arquivo

# %%
import base64

# %%
with open('amazon.csv', 'rb') as file:
    file_content = file.read()

encoded_content = base64.b64encode(file_content)
